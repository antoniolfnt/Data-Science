# %% [markdown]
# <a href="https://colab.research.google.com/github/antoniolfnt/Data-Science/blob/master/CF_gastos_2008.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install numpy
# !pip install scikit-learn

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
files.upload ()
# Out:
#      <input type="file" id="files-257801dc-c0c6-46d3-beb9-ae3401c5cf9c" name="files[]" multiple disabled />
#      <output id="result-257801dc-c0c6-46d3-beb9-ae3401c5cf9c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2008_base_despesa.csv to 2008_base_despesa.csv
# ...

# %%
dados_totais = pd.read_csv ('2008_base_despesa.csv', encoding='utf-8', sep=';')
dados_totais.info()
# Out:
#   Modalidade Empenho  ... Valor Liquidado
# 0         ESTIMATIVO  ...          208500
# 1         ESTIMATIVO  ...          205500
# 2         ESTIMATIVO  ...          208500
# 3         ESTIMATIVO  ...          205500
# 4         ESTIMATIVO  ...          206250
#
# [5 rows x 40 columns]

# %%
#dados_totais.info()
#dados_totais.describe()
#import matplotlib.pyplot as plt
# Chama do historama ' .hist() '
#dados_totais.hist(bins=50, figsize=(20,15))
# Exibe o histograma
#plt.show()
from pandas.plotting import scatter_matrix
attributes = ["Valor Liquidado", "Elemento Despesa"]
# Plota a coorelação
scatter_matrix(dados_totais[attributes], figsize=(12, 8))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-23ed759057db> in <module>()
#       9 attributes = ["Valor Liquidado", "Elemento Despesa"]
#      10 # Plota a coorelação
# ---> 11 scatter_matrix(dados_totais[attributes], figsize=(12, 8))
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_misc.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwargs)
#     132         hist_kwds=hist_kwds,
#     133         range_padding=range_padding,
# --> 134         **kwargs,
#     135     )
#     136
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/misc.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwds)
#      28     n = df.columns.size
#      29     naxes = n * n
# ...
